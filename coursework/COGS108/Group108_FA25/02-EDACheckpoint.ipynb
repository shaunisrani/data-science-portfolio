# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# - Arav Vyawahare: Background research, Data, Conceptualization, Writing – original draft, Writing – review & editing
# - Jude Gamba: Background research, Ethics, Conceptualization, Writing – original draft, Writing – review & editing
# - Shaun Israni: Background and Ethics, Writing – original draft, Writing – review & editing
# - Colin: Background, Research, and Prior Work, Conceptualization, Writing – original draft, Writing – review & editing

# %% [markdown]
# # Research Question

# %% [markdown]
# To what extent can sleep quality metrics (sleep duration, sleep fragmentation, REM latency, and sleep efficiency) predict the risk of developing neurodegenerative diseases such as Alzheimer’s disease, Parkinson's disease, and dementia over time, accounting for demographic and lifestyle variables?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Sleep is one of the most important and necessary parts of our everyday routine, playing a critical role in helping us maintain cognitive function, brain health, memory, mood, emotional regulation, and overall well-being. It plays a vital role in the human health as a whole, allowing the brain to reset itself, remove accumulated toxic byproducts, and adjust neurotransmitter levels, enhancing learning by forming new neural connections and problem-solving abilities **[1]**. Research has shown there is a correlation between different processes that occur during our sleep and consequences with changes to sleep quality.
#
# An emerging concern associated with sleep quality is the link between sleep and neurodegeneration, the loss of neurons connected with various behavioral impairments **[2]**. More generally, neurodegeneration can be seen as the progressive loss of neurons and functionalities. Sleep and sleep quality has become increasingly intertwined and linked to neurodegenerative diseases because of its large impact on brain functionality and regulation. For example, analyses have found that insomnia elevates the risk of all-cause dementia, especially when occurring with a major depressive disorder (MDD) **[3]**. This leads to our main research question: How much of an impact does sleep quality have on the likelihood of developing neurodegenerative disease or other similar health effects? According to studies, having a persistently short sleep duration at ages 50 to 70 compared to persistent normal sleep duration was associated with a 30% risk increase in dementia **[4]**. This was independent of sociodemographic, behavioural, cardiometabolic, and mental health factors as well.
#
# The amount of prior work done on this topic of sleep and neurodegeneration is pretty extensive as studies on our sleep and sleeping habits have a long and storied history. In the past few decades, researchers have made extensive progress on the study of sleep and its effects on all parts of the human body. Recently, researchers have recognized and identified sleep quality as a potential risk factor and symptom of neurodegeneration. However, many aspects of this relationship are still being studied presently and new data and relationships are being found.
#
# - 1 <a name="cite_note-1"></a> [^](#cite_ref-1)
# https://pmc.ncbi.nlm.nih.gov/articles/PMC4651462 – "The Neuroprotective Aspects of Sleep"
#
# - 2 <a name="cite_note-2"></a> [^](#cite_ref-2)
# https://pmc.ncbi.nlm.nih.gov/articles/PMC7593848 – "Impact of Sleep Disturbances on Neurodegeneration: Insight from Studies in Animal Models"
#
# - 3 <a name="cite_note-3"></a> [^](#cite_ref-3)
# https://www.mdpi.com/2077-0383/14/19/7119 – "Sleep Disorders in Neurodegenerative Diseases with Dementia: A Comprehensive Review"
#
# - 4 <a name="cite_note-4"></a> [^](#cite_ref-4)
# https://www.nature.com/articles/s41467-021-22354-2 - "Association of sleep duration in middle and old age with incidence of dementia"

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We’re predicting that there will be a strong correlation between sleep disruption, quality, and deprivation and neurodegenerative diseases such as Alzheimer’s, Parkinson’s, and dementia. Specifically, we hypothesize that observed negative changes in sleep metrics will have adverse effects on the prevalence of blood based bio markers, lewy body counts and cognitive assessment scores (i.e Montreal Cognitive Assessment, Mini Mental State Examination, UPDRS, etc).

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1: Parkinson’s Dataset
#   - Dataset Name: Parkinson's Progression Markers Initiative
#   - Link to the dataset: https://ida.loni.usc.edu/home/projectPage.jsp?project=PPMI
#   - Number of observations: 6138
#   - Number of variables: 84
#   - Description of the variables most relevant to this project:
#
# 	-> Demographics:
#   - PATNO = The patient number that uniquely identifies each patient.
# 	- ENROLL_AGE = The age at which the patient enrolled into the program.
#
# 	-> Patient Health and Genetics:
#   - ENRLPINK1	ENRLPRKN	ENRLSRDC	ENRLNORM	ENRLOTHGV	ENRLHPSM	ENRLRBD	ENRLLRRK2	ENRLSNCA	ENRLGBA → These variables are either gene mutations or underlying medical conditions that could contribute to the later development of Parkinson’s disease.
#
# 	-> Patient Sleep and Quality Metrics:
# - ESS1	Sitting and reading
# - ESS2	Watching TV
# - ESS3	Sitting inactive in a public place (e.g., theater, meeting)
# - ESS4	As a passenger in a car for an hour without a break
# - ESS5	Lying down to rest in the afternoon when circumstances permit
# - ESS6	Sitting and talking to someone
# - ESS7	Sitting quietly after a lunch without alcohol
# - ESS8	In a car, while stopped for a few minutes in traffic
# - These variables are a part of the EPWORTH Sleepiness Scale which is a - numerical measure of daytime sleepiness. This scale (range from 0-3)  tells us how likely a person is to doze off or fall asleep in different everyday situations.
# - SLPDSTRB = General sleep disturbances, DRMVIVID = reports of the patient having vivid dreams (associated with RBD – rem sleep behavior disorder), MVAWAKEN = movements wakes up patients
#
#
# - Descriptions of any shortcomings this dataset has with respect to the project ----
# The dataset contains a large amount of data about sleep metrics, patient information and many other useful biological metrics that may aid in our analysis, however, the amount of data can also be detrimental. Many of tabular data within this dataset requires rigorous cleaning and many columns are irrelevant for the reasearch question we are targetting. The most difficult process will be to wrangle all the neccessary relevant data without misinterpreting the results.
#
#
# -Dataset 2: NACC Alzheimer’s x Sleep Factors
#   - Dataset Name:  Alzheimer’s from NACC: UDS Data Summary Tables
#   - Link to the dataset: https://naccdata.org/
#   - Number of observations: 127759
#   - Number of variables: 47
#   - Description of the Variables Most Relevant to This Project:
#     - Specific variables currently in the cleaned analysis_data dataframe that will be used to test our hypothesis are included here.
#     - Mayo Sleep Questionnaire + SCOPA-sleep = very detailed and validated surveys
# - A. Independent Variables: Sleep Quality & Disruption
#     - NITE (Nighttime Behaviors): Assesses sleep fragmentation, such as awakening the bed partner, rising too early, or excessive napping.
#     - HYPOSOM (Insomnia): Indicates the presence of hyposomnia or insomnia.
#     - RBD (REM Sleep Behavior Disorder): Whether participants appear to act out dreams.
#     - LBSPDRM (Dream Enactment): From questionnaire, asking if the participant has been told they "act out their dreams" (punching, flailing) while sleeping -> key predictor for Lewy Body pathology.
#     - CONSFALL & CONSWKOF (SCOPA-Sleep): Measuring difficulty falling asleep and waking up too often, which serve as proxies/in relation for sleep latency and fragmentation.
#     - CODSAWDY (Daytime Sleepiness: Measures excessive daytime sleepiness, often a consequence of poor nighttime sleep efficiency.
# - B. Dependent Variables: Neurodegenerative Outcomes
#     - NACCETPR (Primary Diagnosis): Clinician's judgment of the primary cause of cognitive impairment. In the dataframe given it compares Alzheimer's (Code 1) vs. Lewy Body/Parkinson's (Code 2) vs. Normal Controls (Code 88).
#     - NACCALZD: A binary indicator (Yes/No) for the presence of Alzheimer's Disease etiology.
#     - NACCLBDS: A binary indicator for Lewy Body Dementia Syndrome.
#     - NACCMMSE & NACCMOCA: Standardized cognitive test scores, where lower scores indicate greater cognitive decline.
#     - NACCACSF, NACCPCSF, NACCTCSF: Cerebrospinal fluid biomarkers for Amyloid Beta, Phosphorylated Tau, and Total Tau. These are the "gold standard" biological indicators of Alzheimer's pathology.
#     - NPLBOD: Neuropathology findings from autopsy indicating the actual presence of Lewy Bodies in the brain.
# - C. Covariates
#     - NACCAPOE: Indicates presence of the APOE ε4 allele, the strongest genetic risk factor for Alzheimer's.
#     - CVHATT & DIABETES: Cardiovascular health history and diabetes status, which are known comorbidities for both sleep apnea and dementia.
# - Descriptions of any shortcomings this dataset has with respect to the project:
#     - While the NACC dataset from the UPS with NP and Genetics plus FTLD and LBD modules is one of the largest datasets of its kind, it has specific limitations regarding objective sleep measures and ideas like sleep architecture.
# 1. Lack of Objective Sleep Data
#     - Our hypothesis requests explicitly with the context for Actigraphy-derived data, including total sleep time, sleep fragmentation index, and polysomnography measures
# In reality, our NACC dataset is primarily clinical and questionnaire-based, which makes variables like NITE, LBSPDRM, and CONSFALL that are subjective reports from the patient or bed partner to be less accurate.
# While there’s a variable indicating if a polysomnogram was done (LBOPOLYS in the LBD module), the dataset we have doesn’t contain the raw granular data files like sleep architecture graphs or ms-level fragmentation indices to give the most specific sleep data records.
# Thus, we are analyzing more perceived sleep quality and observed behaviors on the same depth of variables/factors though, not objective physiological sleep architecture
# 2. High Missingness in Detailed Sleep Metrics
#     - High quality sleep questions (Mayo Sleep Questionnaire, SCOPA survey) located in the LBD module are typically only administered to patients suspected of having Lewy Body Dementia or Parkinson’s.
# This means that the “normal controls” and “Alzheimer's” patients will largely have NA (missing data) for variables like LBSPDRM and CONSFALL.
# Thus, we may encounter difficulty comparing detailed sleep symptoms between the LBD group and the AD/Control groups because the AD/Control groups simply weren't asked those specific questions, and we may have to rely on the coarser NITE variable for cross-group comparison.
# 3. Biomarker Sparse Data
#     - Our hypothesis also looks for the effects on blood-based and CSF biomarkers as included in our dataset.
# The CSF collection (NACCACSF, etc.) is invasive and optional; consequently, a large percentage of rows in our dataset analysis_data have NA for these biomarkers.
# The sample size for the biomarker portion of my analysis may be significantly smaller than the sample size for the clinical diagnosis portion, which could skew and frame analysis in inhibiting ways
# - Additionally, there are also covariates in many demographic and general health variables (age, sex, race, smoking in last 30 days, alcohol abuse history) as well as other biomarker variables (APOe genotype, number of APOE e4 alleles, diagnosis of Lewy Body pathology) that are confounding and we will have to determine how to control for those covariates so that we can clearly see the effect of sleep quality on alzheimer’s and parkinson’s through this complexity. Additionally, since the dataset still includes patients with Frontotemporal Dementia (FTD) (we removed those where FTD is the primary cause) and those biomarkers and sleep signatures greatly differ than those for identifications of people with AD, PD, and LBD, including FTD patients might make the data a little more messy when trying to find a clear signal between sleep and AD/PD biomarkers because of the minor presence of other biomarkers that some patients might have, but it might also strengthen and hone the analysis too through this complexity. Additionally, a good portion of the sleep data comes from questionnaires and surveys (though verified, detailed, and reputable) such as the SCOPA-survey and the Dream Enactment Mayo Sleep Questionnaire, which could cause less accurate results and other potential issues as listed above.

# %% [markdown]
# ### Parkinsons + Alzheimer's Disease Studies: Dataset 1 & 2

# %% [markdown]
# ## Description
#
# - Dataset 1:
# This dataset combines clinical, metabolomic, and sleep-related information for individuals in various Parkinson’s disease (PD) related cohorts.
#
# The metabolomic data file contains thousands of rows, each representing a single measured feature detailing the testing and result for a single patient. Each row includes contains plasma LC/MS measurements from individuals enrolled as Parkinson’s disease patients, prodromal participants, or healthy controls. For each participant, multiple features are measured using untargeted mass spectrometry, and each feature is defined by TESTNAME. The values in the column TESTNAME take the form MZxxx.xx_RTyyy.yy_mmm where MZxxx.xx indicates a mass to charge ratio of xxx.xx, RTyyy.yy is the retention time in seconds, and mmm indicates either positive or negative ionization mode. These molecular features capture many different types of chemicals that are important in neurodegenerative diseases. They include purines involved in energy and cell signaling, lipids linked to lysosomal function, molecules that reflect oxidative stress, markers of inflammation, and indicators of environmental or dietary exposures.
#
# The Participant Status dataset provides demographic and diagnostic information about each individual, including sex, cohort classification (e.g., Healthy Controls, Prodromal, SWEDD, Early Imaging, and Parkinson's Disease), and clinical visit numbers (e.g., V04). These identifiers allow researchers to link biomarker data with disease status, time points, and potential progression markers. The structured visit labels indicate tracking over time, which is helpful for studying early disease signals and development.
#
# The Epworth Sleepiness Scale (ESS) dataset measures daytime sleepiness across eight scenarios (e.g., sitting and reading, traveling in a car). Each item (ESS1–ESS8) is scored from 0 to 3, and the total ESS score ranges from 0 to 24. Higher values indicate increased daytime sleepiness, and scores >10 typically indicate excessive daytime sleepiness, which can be associated with neurological conditions such as PD (Parkinson's Disease) or REM sleep behavior disorder. The dataset also includes visit dates, baseline vs. later visits, and identifiers that allow linkage across the different files through PATNO (patient number).
#
# The REM Sleep Behavior Disorder (RBD) Questionnaire dataset adds another relevant sleep-related dimension. It measures the likelihood and severity of different sleep-related behaviors. More specifically, it measures how often people act out their dreams or lose normal muscle relaxation during REM sleep—problems that are common early signifiers of Parkinson’s disease. Each question reflects how frequent or severe these behaviors are, and higher scores mean stronger signs of possible RBD.
#
# - Dataset 2:
#     - This dataset is a processed subset of the National Alzheimer’s Coordinating Center (NACC) Uniform Data Set (UDS), containing 127,759 observations and 56 variables. It aggregates longitudinal clinical, genetic, and neuropathological data from Alzheimer’s Disease Centers across the US. The dataset tracks participants over time to monitor transitions from normal cognition to mild cognitive impairment (MCI) and dementia. It specifically combines general health information with specialized modules for Lewy Body Dementia (LBD) and Frontotemporal Lobar Degeneration (FTLD) to capture detailed sleep and motor symptoms. The population includes healthy controls, those with subjective cognitive decline, and patients diagnosed with Alzheimer’s Disease (AD), Parkinson’s Disease (PD), or Lewy Body Dementia (LBD).
#
# ## Interpretation of What These Metrics Mean
# Dataset 1:
#
# Together, these metrics help researchers see whether patterns in a person's health (sleep, metabolic changes in blood) relate to Parkinson’s disease, early warning signs of the disease, or sleep problems. For example, if people with higher sleepiness scores (ESS) or stronger RBD symptoms show different metabolite patterns, it could suggest links between sleep disruption, metabolism, and early neurodegeneration. The visit labels and patient IDs let us track the same person over time, so changes in their metabolite levels and sleep levels may reflect disease progression or treatment effects. Because the dataset uses untargeted mass spectrometry, it captures thousands of raw features rather than only known metabolites, which can help uncover unexpected biological changes connected to both Parkinson’s disease and sleep dysfunction.
#
# Dataset 2:
#
# These metrics allow researchers to correlate sleep disturbances with specific neurodegenerative outcomes and cognitive decline.
# - Cognitive Performance (MMSE & MoCA):
#     - NACCMMSE (Mini-Mental State Exam): Measured on a scale of 0 to 30. In this dataset, the median is 28, indicating a generally cognitively healthy baseline for many, but values range down to 0. Generally, scores 24–30 indicate no impairment, 18–23 indicate mild impairment, and 0–17 indicate severe impairment.
#     - NACCMOCA (Montreal Cognitive Assessment): Also a 30-point scale but more sensitive to mild impairment. The dataset median is 25. Scores $\ge$ 26 are considered normal.
# - Sleep Quality Indices:
#     - NITE (Nighttime Behaviors): A binary metric (0=Absent, 1=Present) from the NPI-Q. A value of 1 indicates the patient exhibits sleep fragmentation behaviors like awakening the bed partner, rising too early, or pacing at night.
#     - LBSPDRM (REM Sleep Behavior Disorder): A binary metric (0=No, 1=Yes) from the Mayo Sleep Questionnaire asking if the patient "acts out their dreams" (punching, flailing). A 1 is a strong prodromal predictor for Lewy Body pathology (Parkinson’s/LBD) rather than Alzheimer's.
#     - SCOPA-Sleep (CONSFALL, CONSWKOF): Ordinal scales ranging from 0 (Not at all) to 3 (A lot). Higher values indicate greater severity of sleep latency (trouble falling asleep) or fragmentation (waking too often).
# - Clinical Diagnosis (NACCETPR):
#     - A categorical variable representing the primary etiology of cognitive impairment. We filtered the data to focus on Code 1 (Alzheimer's Disease), Code 2 (Lewy Body Disease/Parkinson's), and Code 88 (Normal Controls/No impairment).
# - Biomarker Availability (NACCACSF):
#     - A binary flag (0/1) indicating whether cerebrospinal fluid (CSF) data for Amyloid Beta or Tau is available for the patient. A 1 indicates the presence of this "gold standard" biological data.
#
# - Data Cleaning and Processing
# The original raw dataset contained thousands of variables and "junk codes" specific to NACC entry protocols
# 1. Missing Data Handling: NACC uses codes like -4 (Not available), 9 (Unknown), 8 (Not applicable), and 88 to represent missingness. We converted all occurrences of these integers into standard NA values to prevent skewing statistical calculations (e.g., treating a missing age as 999).
# 2. Filtering: We filtered the dataset to exclude patients with Frontotemporal Dementia (FTD) as a primary cause, as their sleep/biomarker profiles differ significantly from our target AD/PD populations. We retained only rows where the Primary Diagnosis (NACCETPR) was Alzheimer's, Lewy Body/PD, or Normal.
# 3. Type Conversion: Categorical variables (Sex, Race, Diagnosis) were converted from integers to factors to ensure proper grouping in analysis.
#
# ## Potential Concerns and Limitations
#
# Dataset 1:
#
# A major concern is that the metabolomic dataset is enormous and unfiltered, containing hundreds of thousands of individual features. Untargeted metabolomics data often includes noise, redundant features, isotope/adduct peaks, or unidentified mass signals. Without preprocessing, apparent group differences may reflect technical variation rather than biological differences.
#
# Another concern is sample bias. The dataset appears to come from research volunteers enrolled in a PD study, which means participants may not represent the general population—volunteers are often healthier, more motivated, and more educated. PD participants may be recruited from specialized clinics, leading to diagnostic or socioeconomic biases. Furthermore, repeated visit data may not be complete for all patients, raising the possibility of missingness bias if individuals with more severe progression fail to return for later visits.
#
# Finally, ESS scores are self-reported and may be influenced by subjective factors such as mood, understanding of the questionnaire, or recall bias. Sleepiness also fluctuates with medication use, comorbid sleep disorders, or lifestyle factors not included in the dataset. As a result, ESS should be interpreted cautiously and ideally complemented with objective sleep measures.
#
# Dataset 2:
#
# A major concern is the extreme missingness in the detailed sleep and biomarker variables.
#
# - Systematic Missingness (MNAR): The detailed sleep metrics (like LBSPDRM and CONSFALL) are part of the LBD Module and In our summary statistics, LBSPDRM has 126,933 NAs out of 127,759 rows (>99% missing). This is because this module is typically only administered to patients already suspected of Parkinson's or LBD, which means that the "Normal" and "Alzheimer's" patients rarely have this data. This as a result makes our cross-group comparison difficult.
#
# - Biomarker Scarcity: Similarly, the biomarker availability flags (NACCACSF) have very low means (~0.05), indicating that only ~5% of participants underwent the invasive lumbar puncture required for CSF data.
#
# - Subjectivity: Variables like NITE are based on caregiver or patient reports, not objective actigraphy. Depression (DEPRS) and anxiety are confounding comorbidities/factors that can alter sleep independent of neurodegeneration, and these require careful statistical control.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Dataset #1
#
# ### Import the data into 3 separate data frames
# - ess_df will hold the data regarding the Epsworth Sleepiness Scale Questionaire
# - rem_df will hold the data for the different types of sleep quality questions
# - status_df will hold the patient numbers(PATNO) along with their cohort group and genetic mutations

# %%
import pandas as pd
import os

# Load the data files (assuming they are in the same directory)
ess_df = pd.read_csv('data/00-raw/Epworth_Sleepiness_Scale_12Nov2025.csv')
rem_df = pd.read_csv('data/00-raw/REM_Sleep_Behavior_Disorder_Questionnaire_12Nov2025.csv')
status_df = pd.read_csv('data/00-raw/Participant_Status_12Nov2025.csv')

# %% [markdown]
# #### Prepare the ESS Data
# The data inside the ESS sleep questionaire has multiple rows with the same PATNO because the questionaire is taken over time. To account for this and maintain one row for each patient in our data frame, we will only keep the first recorded date for each patient which will serve as a basline for all analysis. We label this initial row as **BL**.
#
# The ESS file contains 8 columns which correspond to a question in the Epsworth sleepiness scale. The response to each question is a value of 0 - 3 which corresponds to the severity of drowsniness at a certain point in the day.

# %%
# 1. Filter for baseline visit
ess_baseline_df = ess_df[ess_df['EVENT_ID'] == 'BL'].copy()

# 2. Define the ESS columns for summation.
ess_cols = ['ESS1', 'ESS2', 'ESS3', 'ESS4', 'ESS5', 'ESS6', 'ESS7', 'ESS8']

# 3. Ensure columns are numeric (converts non-numeric values to NaN)
ess_baseline_df[ess_cols] = ess_baseline_df[ess_cols].apply(pd.to_numeric, errors='coerce')

# 4. Calculate the Total ESS score (summing all 8 items). 
ess_baseline_df['Total_ESS_Score'] = ess_baseline_df[ess_cols].sum(axis=1)

# 5. Calculate the average ESS score over time
ess_df[ess_cols] = ess_df[ess_cols].apply(pd.to_numeric, errors='coerce')
ess_df['Total_ESS_Score_visit'] = ess_df[ess_cols].sum(axis=1)
ess_avg = ess_df.groupby('PATNO', as_index=False)['Total_ESS_Score_visit'] \
                .mean() \
                .rename(columns={'Total_ESS_Score_visit': 'Avg_ESS_Score'})


# 5. Select only PATNO and the new Total_ESS score
ess_tidy = ess_baseline_df[['PATNO', 'Total_ESS_Score']].merge(ess_avg, on='PATNO', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EVENT_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 1. Filter for baseline visit
# ----> 2 ess_baseline_df = ess_df[ess_df['EVENT_ID'] == 'BL'].copy()
#       4 # 2. Define the ESS columns for summation.
#       5 ess_cols = ['ESS1', 'ESS2', 'ESS3', 'ESS4', 'ESS5', 'ESS6', 'ESS7', 'ESS8']
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'EVENT_ID'

# %% [markdown]
# #### Preparing the REM data
#
# Similar to the ESS dataframe, we want to only keep the first recorded row in the data set for each patient. We label this baseline **BL** and filter the file to only keep these rows for the final data frame.
#
# Our target variables are PATNO, SLPDSTRB, MVAWAKEN, and DRMVIVID which correspond to the occurence of certain sleep behaviors amongst patients.
#
# - SLPDSTRB = 0 or 1
# - MVAAWAKEN = 0 or 1
# - DRMVIVID = 0 or 1

# %%
# 1. Filter for baseline visit
rem_baseline_df = rem_df[rem_df['EVENT_ID'] == 'BL'].copy()

# 2. Select the required REM sleep columns and PATNO
rem_cols = ['PATNO', 'SLPDSTRB', 'MVAWAKEN', 'DRMVIVID']
rem_tidy = rem_baseline_df[rem_cols]

# 3. Remove any residual duplicates, keeping the first entry (should be minimal after BL filter)
rem_tidy = rem_tidy.drop_duplicates(subset=['PATNO'], keep='first').astype(int)

# print("REM Tidy Data Head:")
rem_tidy.head()

# %% [markdown]
# #### Preparing the Genetics Data
#
# Inside the participant status file, there are multiple columns corresponding to whether a patient has or does not have a certain genetic mutation. Each entry is between 0 and 1.
#
# We target only these genetic variables along with patient number and lastly account for any duplicates within the dataset to align with similar practices in previous steps.
#
# - PATNO = int value starting from 3000
# - COHORT = 1: Parkinsons, 2: Healthy Control, 3: SWEDD, 4: Prodromal
# - ENROLL_AGE = float
# - ENRLPINK1 - ENRLGBA = value of 0 or 1

# %%
genetic_cols_to_keep = [
    'PATNO', 'ENROLL_AGE', 'COHORT', 'ENRLPINK1', 'ENRLPRKN', 'ENRLSRDC', 'ENRLNORM',
    'ENRLOTHGV', 'ENRLHPSM', 'ENRLRBD', 'ENRLLRRK2', 'ENRLSNCA', 'ENRLGBA'
]

status_tidy = status_df[genetic_cols_to_keep].copy()

# 1. Remove any duplicates just in case, keeping the first entry.
status_tidy = status_tidy.drop_duplicates(subset=['PATNO'], keep='first')

# print("Status/Genetics Tidy Data Head:")
status_tidy.head()

# %% [markdown]
# #### Merging Dataframes
#
# We merge the 3 data frames with an outer join to preserve all the patients recorded in the participant status file. To further follow tidy data practices, we rename the 3 REM sleep metrics to more descriptive variable names. This will help in the readability and interpretibility of our analysis later on.

# %%
# 1. Merge ESS and REM data
merged_df = pd.merge(ess_tidy, rem_tidy, on='PATNO', how='outer')

# 2. Merge with Status/Genetics data
final_tidy_df = pd.merge(merged_df, status_tidy, on='PATNO', how='outer')

# 3. Tidy Data Cleanup: Rename columns to be more descriptive, Reorder columns
final_tidy_df.rename(columns={
    'SLPDSTRB': 'REM_Sleep_Disturbance',
    'MVAWAKEN': 'Motor_Move_Waking',
    'DRMVIVID': 'Vivid_Dreams',
    'ENROLL_AGE': 'Age',
    'COHORT': 'Cohort',
    'PATNO': 'Patient_Number'
}, inplace=True)

cols = final_tidy_df.columns.tolist()
new_order = ['Patient_Number', 'Age', 'Cohort'] + [c for c in cols if c not in ('Patient_Number', 'Age', 'Cohort')]
final_tidy_df = final_tidy_df[new_order]
cols

# Save the final DataFrame to a CSV file
output_dir = 'data/02-processed'
os.makedirs(output_dir, exist_ok=True)
final_out_file = os.path.join(output_dir, 'parkinsons_tidy_data.csv')
final_tidy_df.to_csv(final_out_file, index=False)

print("Final Tidy DataFrame Head:")
final_tidy_df.head()

# %% [markdown]
# ### Dataset #2

# %% [markdown]
# #### Data Cleaning and Merging Steps
#
# - Summary of Data Cleaning & Processing Steps
# 1. Variable Selection: We started with the massive raw NACC dataset (potentially 2,000+ columns) and filtered it down to a targeted subset of ~56 variables. These variables were chosen based on our hypothesis to capture:
#     - Predictors: Sleep metrics (NPI-Q, Mayo Sleep Questionnaire, SCOPA-Sleep).
#     - Outcomes: Clinical diagnoses (AD, LBD, PD), cognitive scores (MMSE, MoCA), and biomarkers (CSF, Autopsy).
#     - Covariates: Demographics, genetics (APOE), and medical history.
# 2. "Junk Code" Cleaning: The NACC dataset uses specific integers to represent missing or inapplicable data. We replaced the following codes with NaN (Not a Number) to prevent statistical errors, these are:
#     - -4: Not available / form not submitted.
#     - 9, 99, 999: Unknown.
#     - 8, 88: Not applicable / Not assessed.
#     - Note: Applied this replacement only to numeric columns as needed to avoid breaking text identifiers like NACCID.
# 3. Cohort Filtering (Row Selection): To test our specific hypothesis, we filtered the participants to include only three distinct groups:
#     - Alzheimer's: Primary Etiology (NACCETPR) = 1.
#     - Lewy Body / Parkinson's: Primary Etiology (NACCETPR) = 2.
#     - Normal Controls: Cognitive Status (COGSTAT) = 2.
#     - Note: This step automatically excluded participants with Frontotemporal Dementia (FTD) or other primary causes to reduce noise and cloud analyses with differing biomarkers
#
# - Through feature engineering, we were able to create a single, clean Diagnosis column to label these three groups (Alzheimers, Lewy Body / PD, Normal Control). This makes plotting and statistical comparison with techniques like ANOVA, clustering, and regression much easier.
# - Through type conversion, we converted categorical variables (like SEX, RACE, NACCAPOE) from integers into categorical types (factors) so Python treats them as groups rather than numbers, without breaking text identifiers.

# %%
import pandas as pd
import numpy as np

# 1. Load the dataset
# Replace 'NACC_data.csv' with the actual path to your file if it's different
my_data = pd.read_csv(r'data/NACC_data.csv')

# 2. Define the "Shopping List" of variables to keep
variables_to_keep = [
    # Identifiers
    "NACCID", "VISITYR", "NACCETPR", 
    
    # Demographics & Covariates
    "NACCAGE", "SEX", "EDUC", "RACE", "NACCINCM",
    "NACCAPOE", "NACCNE4S", "FADMOM", "FADPOP",
    "TOBAC30", "SMOKYRS", "ALCOHOL", "NACCACT",
    "CVHATT", "CVAFIB", "CVCHF", "CVSTROKE", "DIABETES", "DEPRS",
    
    # Sleep Metrics (Predictors)
    "NPIQINF", "NITE", "HYPOSOM", "RBD", 
    "LBSPDRM", "LBSPTALK", "LBSPMOVE", "LBSCDRM",
    "CONSFALL", "CONSWKOF", "CONSLYAW", "CONSWKER", "CONSLTTL", "CODSAWDY",
    
    # Outcomes (Diagnoses & Scores)
    "COGSTAT", "NACCALZD", "PARK", "NACCLBDS", "FTD",
    "NACCMMSE", "NACCMOCA",
    
    # Motor Exams (UPDRS)
    "LBUMSPCH", "LBUMFACE", "LBUMREST", "LBUMACT", "LBUMRIG", 
    "LBUMFALL", "LBUMGAIT", "LBUMPOST", "LBUMBRAD",
    
    # Biomarkers
    "NACCACSF", "NACCPCSF", "NACCTCSF", "NACCLEWY", "NPLBOD"
]

# 3. Create the analysis dataframe
# We intersect the list with columns that actually exist to avoid errors
existing_vars = [col for col in variables_to_keep if col in my_data.columns]
analysis_data = my_data[existing_vars].copy()

# 4. Clean "Junk" Codes
# Replace -4, 8, 9, etc. with NaN (only in numeric columns)
junk_codes = [-4, 8, 9, 88, 99, 999]

# Iterate over numeric columns and replace junk codes
numeric_cols = analysis_data.select_dtypes(include=[np.number]).columns
for col in numeric_cols:
    analysis_data[col] = analysis_data[col].replace(junk_codes, np.nan)

# 5. Filter Rows: Keep AD, LBD/PD, and Normal Controls
# Logic: Keep if Primary Diagnosis is AD (1), LBD (2), OR if Cognitive Status is Normal (2)
analysis_data = analysis_data[
    (analysis_data['NACCETPR'] == 1) | 
    (analysis_data['NACCETPR'] == 2) | 
    (analysis_data['COGSTAT'] == 2)
].copy()

# 6. Create the clean 'Diagnosis' column
conditions = [
    analysis_data['NACCETPR'] == 1,
    analysis_data['NACCETPR'] == 2,
    analysis_data['COGSTAT'] == 2
]
choices = ['Alzheimers', 'Lewy Body / PD', 'Normal Control']

analysis_data['Diagnosis'] = np.select(conditions, choices, default=np.nan)

# 7. Convert categorical columns to 'category' type (Factor equivalent)
categorical_cols = [
    "SEX", "RACE", "NACCAPOE", "NACCNE4S", "TOBAC30", "ALCOHOL",
    "CVHATT", "CVAFIB", "CVCHF", "DIABETES", "NPIQINF", "NITE", "HYPOSOM", "RBD",
    "LBSPDRM", "LBSPMOVE", "LBSCDRM", "CONSFALL", "CONSWKOF", "CONSLYAW", 
    "CONSWKER", "CONSLTTL", "CODSAWDY", "COGSTAT", "NACCALZD", "PARK", 
    "NACCLBDS", "FTD", "NACCLEWY", "NPLBOD", "Diagnosis"
]

# Only convert columns that actually exist in the filtered data
existing_cat_cols = [col for col in categorical_cols if col in analysis_data.columns]
analysis_data[existing_cat_cols] = analysis_data[existing_cat_cols].astype('category')

# The final check: 
print("Final Data Dimensions:", analysis_data.shape) # dimensions of dataframe
print("\nCounts per Diagnosis Group:")
print(analysis_data['Diagnosis'].value_counts())
print("\nFirst 5 rows:")
display(analysis_data.head())
# Out:
# /tmp/ipykernel_333/1347876097.py:6: DtypeWarning: Columns (20,22,24,26,28,41,44,46,48,51,61,63,65,67,69,71,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,156,165,176,179,189,217,220,222,224,226,228,230,232,234,236,238,240,242,244,246,248,250,252,254,256,258,260,262,264,266,268,270,272,397,399,401,421,423,432,445,454,494,574,605,613,638,674,690,707,710,727,744,804,809,810,811,812,820,831,833,835,837,843,904,959,960,961,969,970,971,972,982,1004,1007,1010,1029,1034,1204,1208,1211,1407,1409,1411,1412,1414,1421,1423,1425,1426,1433,1435,1437,1439,1440,1447,1462,1476,1490,1504,1506,1558,1560,1562,1564,1566,1568,1570,1572,1574,1576,1578,1580,1582,1584,1586,1588,1590,1592,1594,1596,1598,1600,1602,1604,1606,1608,1610,1612,1815) have mixed types. Specify dtype option on import or set low_memory=False.
#   my_data = pd.read_csv(r'data/NACC_data.csv')
# Final Data Dimensions: (12465, 47)
#
# Counts per Diagnosis Group:
# Diagnosis
# Alzheimers        6517
# Normal Control    5460
# Lewy Body / PD     488
# Name: count, dtype: int64
#
# First 5 rows:
#        NACCID  VISITYR  NACCETPR  NACCAGE SEX  EDUC RACE NACCAPOE NACCNE4S  \
# 0  NACC002909     2022       1.0     70.0   1  16.0  1.0      2.0      1.0
# 1  NACC002909     2024       1.0     71.0   1  16.0  1.0      2.0      1.0
# 2  NACC002909     2025       1.0     72.0   1  16.0  1.0      2.0      1.0
# 4  NACC003487     2023       NaN     66.0   1  16.0  1.0      6.0      0.0
# 6  NACC004352     2021       1.0     63.0   2  16.0  1.0      NaN      NaN
#
#   TOBAC30  ...  LBUMFACE LBUMGAIT LBUMPOST LBUMBRAD NACCACSF NACCPCSF  \
# 0     0.0  ...       NaN      NaN      NaN      NaN      0.0      0.0
# 1     NaN  ...       NaN      NaN      NaN      NaN      0.0      0.0
# 2     NaN  ...       NaN      NaN      NaN      NaN      0.0      0.0
# 4     0.0  ...       NaN      NaN      NaN      NaN      0.0      0.0
# 6     0.0  ...       NaN      NaN      NaN      NaN      0.0      0.0
#
#   NACCTCSF NACCLEWY NPLBOD       Diagnosis
# 0      0.0      NaN    NaN      Alzheimers
# 1      0.0      NaN    NaN      Alzheimers
# 2      0.0      NaN    NaN      Alzheimers
# 4      0.0      NaN    NaN  Normal Control
# 6      0.0      NaN    NaN      Alzheimers
#
# [5 rows x 47 columns]

# %%
import os

# Define the output directory and file name
output_dir = "data/02-processed"
os.makedirs(output_dir, exist_ok=True)  # Create the directory if it doesn't exist
final_output_file = os.path.join(output_dir, "focused_nacc_data.csv")

# Save the dataframe to CSV
# index=False avoids saving the row numbers as a separate column
analysis_data.to_csv(final_output_file, index=False)

# Confirmation message
print(f"\nSuccessfully saved processed data to: {final_output_file}")
# Out:
# Successfully saved processed data to: data/02-processed/focused_nacc_data.csv

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Section 1 of EDA - Parkinsons Dataset (ESS Scores)
#
# In the following sections, we examine several sleep-related features across four Parkinson’s-relevant cohorts: Parkinson’s Disease, Prodromal, SWEDD, and Healthy Controls. Our goal is to determine whether patterns of sleep disruption differ between healthy individuals and those diagnosed with—or at elevated risk for—Parkinson’s disease. We analyze both daytime sleepiness (ESS scores) and REM-related disturbances, focusing on three reported symptoms (related to REM disturbances). Across all of our distribution based visualizations, we compare healthy versus unhealthy patient groups to assess whether these metrics and distributions separate these populations.
#
# First lets look at what our shape

# %%
park_df = pd.read_csv('data/02-processed/parkinsons_tidy_data.csv')
park_df.shape
# Out:
# (2, 1)

# %% [markdown]
# There are 7772 patients in the data frame and 17 features for each patient.
#
# Now lets look at what our dataframe looks like.

# %%
park_df.head(10)
# Out:
#           version https://git-lfs.github.com/spec/v1
# 0  oid sha256:335280b80f26ed673add1f11593c7afbf1a...
# 1                                        size 405661

# %% [markdown]
# From the 10 entries, we can already see that many of the entries for some patients are Nan which we will take into account for our analysis later.
#
# To account for demographic features like age, let's view the average ages for each cohort in our dataset.

# %%
ages = park_df.groupby('Cohort')['Age']
ages.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ages = park_df.groupby('Cohort')['Age']
#       2 ages.describe()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Cohort'

# %% [markdown]
# In the table, we can see that the average age for each cohort is around early to late 60s. This could lead to us finding age as a confounding variable for parkinsons with some patient ages reaching up to 90 for cohort 4.
#
# Next lets see the distribution of the dataframe by looking at the counts of each cohort. It could tell us how biased our data set may be.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.countplot(park_df, x='Cohort', hue='Cohort', palette='deep')

plt.legend(['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal'])
plt.title('Cohort Counts')
plt.show()

# %% [markdown]
# As we can see in the countplot, there are vastly more patients part of the prodromal cohort compared to the parkinsons and healthy control. The SWEDD cohort is the smallest group and it was noted in the docuentation in the dataset that this group could be dropped for analysis.

# %%
plot_df = park_df.copy()
plot_df["Avg_ESS_Score"] = pd.to_numeric(plot_df["Avg_ESS_Score"], errors="coerce")
plot_df["Cohort"] = pd.to_numeric(plot_df["Cohort"], errors="coerce")


plt.figure(figsize=(10, 6))

sns.kdeplot(
    data=plot_df,
    x="Avg_ESS_Score",
    hue="Cohort",        # ← use numbers directly
    fill=True,
    common_norm=False,
    alpha=0.35,
    linewidth=2,
    palette='viridis'
)

plt.title("KDE of ESS Avg Score by Cohort")
plt.xlabel("Avg ESS Score (0–24)")
plt.ylabel("Density")
plt.xlim(0, 24)
plt.legend(['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal'])
plt.tight_layout()
plt.show()

# %% [markdown]
# This Kernel Density Estimation (KDE) plot compares the average Epworth Sleepiness Scale (ESS) scores across four cohorts: Parkinson’s Disease, Healthy Controls, SWEDD, and Prodromal. ESS ranges from 0–24, with higher scores indicating greater daytime sleepiness.
#
# Unexpectedly, the Healthy Control cohort shows the widest spread and the largest right-tail density, indicating that a subset of these participants score 10 or higher on the ESS. This suggests that there is greater variability in sleepiness among our healthy control individuals, potentially due to lifestyle factors, differing sleep routines, or other unrelated factors.
#
# The Parkinson’s and Prodromal cohorts show moderate but more compact ESS distributions, peaking around the mid-range (4–6). Meanwhile, SWEDD participants have the lowest ESS values, forming a narrow, low-sleepiness profile.
#
# This pattern doesn’t imply that sleep has no role in Parkinson’s disease. Instead, it shows that the ESS --- which measures general daytime sleepiness --- is not that strong or specific of a marker for early Parkinson’s or prodromal symptoms

# %%
plot_df["Total_ESS_Score"] = pd.to_numeric(plot_df["Total_ESS_Score"], errors="coerce")
plot_df["Cohort"] = pd.to_numeric(plot_df["Cohort"], errors="coerce")

# Drop missing ESS scores
#plot_df = plot_df.dropna(subset=["Total_ESS_Score", "Cohort"])

plt.figure(figsize=(10, 6))

sns.kdeplot(
    data=plot_df,
    x="Total_ESS_Score",
    hue="Cohort",        # ← use numbers directly
    fill=True,
    common_norm=False,
    alpha=0.35,
    linewidth=2,
    palette='viridis'
)

plt.title("KDE of ESS Total Score by Cohort (Baseline)")
plt.xlabel("Total ESS Score (0–24)")
plt.ylabel("Density")
plt.xlim(0, 24)
plt.legend(['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal'])
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that plotting the Total ESS Score doesn't really change much about what we can gather from at least healthy --- unhealthy patients. The healthy control seems to remain around the same distribution with the most notable difference being the Parkinson's and Prodromal distributions becoming more concentrated with higher peaks around the average.
#
# - just as a note, this total ESS Score was the ESS score that patients received on their first visit (doesn't account for later visits)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=plot_df,
    x="Cohort",
    y="Total_ESS_Score",
    palette="Set2"
)

plt.title("Boxplot of ESS Total Score by Cohort")
plt.xlabel("Cohort (1=PD, 2=Healthy Control, 3= SWEDD, 4=Prodromal)")
plt.ylabel("Total ESS Score (0–24)")
plt.show()
# Out:
# /tmp/ipykernel_31540/1376618893.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# These boxplots are representing the four different cohorts of the study: Parkinson's Disease, Healthy Control, SWEDD (false positive), and Prodromal.
#
# (Represents either through ESS Total -- on first visit -- or ESS Average -- over all visits)
# Overall, the distributions appear broadly similar, with all cohorts showing ESS scores centered in the 3–8 range, indicating only mild to moderate daytime sleepiness on average. However, the Healthy Control group shows the lowest median ESS and the tightest, most compact distribution, indicating that their sleepiness levels are more uniform and generally lower. In contrast, the Parkinson’s and Prodromal groups display slightly higher medians and wider spreads, suggesting greater variability and somewhat elevated daytime sleepiness among individuals with Parkinson’s disease or those at risk. These trends support the expectation that healthy individuals tend to exhibit lower ESS scores compared to those diagnosed or related to neurodegenerative disease.
#
# However, these results aren't too convincing of a large difference at least when it comes to the distributions of ESS Scores within healthy and unhealthy individuals.

# %%
plt.figure(figsize=(10,5))
    
ax = sns.violinplot(park_df, x='Cohort', y='Total_ESS_Score')

ax.set_xticklabels(['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal'])
plt.xlabel('Cohort', fontsize=14)
plt.ylabel('ESS Score (0-24)', fontsize=14)

plt.title('Total ESS Score by Cohort', fontsize=16)
plt.show()

plt.figure(figsize=(10,5))
# Out:
# /tmp/ipykernel_31540/4003509313.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal'])

# %% [markdown]
# As we can see in the violin plots, the distribution shows that the mean ESS score for the healthy control is less than the average of the other groups. Furthermore, ESS scores for the healthy control are more concentrated around values less than 5 while the other 3 cohorts all have their greatest width of their distribution over a value of 5. This finding supports our hypothesis that poor sleep quality could lead to a higher chance of developing neurodigenerative diseases like parkinsons. This violin plot only shows the baseline ESS score, now lets look at the average ESS scores over time after accounting for multiple tests by each patient.

# %%
ax = sns.violinplot(park_df, x='Cohort', y='Avg_ESS_Score')

ax.set_xticklabels(['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal'])
plt.xlabel('Cohort', fontsize=14)
plt.ylabel('ESS Score (0-24)', fontsize=14)

plt.title('Average ESS Score by Cohort', fontsize=16)
plt.show()
# Out:
# /tmp/ipykernel_31540/2184645315.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal'])

# %% [markdown]
# Now accounting for averages, the healthy control median still stays below the means of the other 3 cohorts which continues to support our claim. This indicates that the central tendency of the healthy control group lies below the central tendency of the other 3 groups. Looking at the width of the distributions for Parkinsons, SWEDD, and Prodromal, overall the width has decreased leading to a smoother distribution curve.
#
# ESS score is only a qualitiative questionaire which could have many dependencies on other factors we may have not accounted for. For example, it does not account for the person's daily activities such as work or hobbies. To find further evidence to refute the null hypothesis that sleep quality metrics don't have an effect on parkinsons, lets analyze REM sleep behaviors.

# %% [markdown]
# #### Section 2 of EDA Parkinson's Dataset - (REM Sleep Metrics)

# %% [markdown]
# We are analyzing 3 different REM sleep metrics: general sleep disurbance, vivid dreams, and motor move waking. These three variables contribute to the overall sleep quality of each patient and could serve as a good indicator of whether we can reject our null hypothesis. Specifically, general sleep disturbances is a variable for overall sleep disruptions that inhibit normal sleep, vivid dreams is a indicator of REM behavior disorder, and motor move waking could be a byproduct of nightmares or involuntary movements that lead to sleep disruption. All together, these metrics help to illustrate whether a patient has healthy sleep quality.
#
# For each variable, let us plot the percentage of people within in each cohort that say they experience each.

# %%
def plot_rem_var(var):
    df = park_df.copy()

    df[var] = pd.to_numeric(df[var], errors="coerce")

    # Compute percentages per cohort
    pct = df.groupby("Cohort")[var].mean() * 100
    pct_df = pct.reset_index()
    pct_df.columns = ["Cohort", "Percent"]

    plt.figure(figsize=(6, 5))

    # Match style of your countplot call
    ax = sns.barplot(
        data=pct_df,
        x="Cohort",
        y="Percent",
        hue="Cohort",
        palette="viridis"
    )

    labels = ['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal']

    handles, _ = ax.get_legend_handles_labels()
    ax.legend(handles, labels, title="Cohort")
    plt.title(var.replace("_", " "))
    plt.xlabel("Cohorts")
    plt.ylabel("Percent with Behavior")
    plt.ylim(0, 100)

    # Annotate bars
    for p in ax.patches:
        height = p.get_height()
        ax.annotate(
            f"{height:.1f}%",
            (p.get_x() + p.get_width() / 2, height),
            ha="center", va="bottom"
        )

    plt.show()

# %% [markdown]
# Plot for Sleep Disturbance

# %%
plot_rem_var('REM_Sleep_Disturbance')

# %% [markdown]
# The healthy control group has the lowest proportion of patients experiencing REM sleep disturbances. There is an outlier for SWEDD which holds the highest proportion. However, earlier we discussed how this group accounts for less than 1 percent of the overall population in our dataset so it's results could have little impact on our overall conclusions.

# %%
plot_rem_var('Motor_Move_Waking')

# %% [markdown]
# Similarily, the healthy control remains the cohort with the lowest proportion.

# %%
plot_rem_var('Vivid_Dreams')

# %% [markdown]
# Interestingly, for vivid dreams, the proportion is similar between the parkinsons cohort and the healthy control. The healthy control is now only less than 0.1 percent behind the percentage of parkinsons. This could indicate that vivid dreams could be a result of another confounding variable we have not accounted for such as the prevalence of underlying REM sleep disorder or other related ailments.

# %%
cohort_labels = ['Parkinsons', 'Healthy Control', 'SWEDD', 'Prodromal']
def plot_rem_kde(df, rem_col):
    df_var = df.dropna(subset=[rem_col])

    plt.figure(figsize=(10, 6))
    sns.kdeplot(
        data=df_var,
        x=rem_col,
        hue='Cohort',
        fill=True,
        common_norm=False,
        alpha=0.35,
        linewidth=2,
        palette="viridis"
    )

    plt.title(f"KDE Plot of {rem_col.replace('_', ' ')} by Cohort")
    plt.xlabel(f"{rem_col} (0 = No, 1 = Yes)")
    plt.ylabel("Density")
    plt.xlim(-0.1, 1.1)
    plt.legend(
    title="Cohort",
    labels=["Parkinsons", "Healthy Control", "SWEDD", "Prodromal"],
    loc="upper right"
)

# %%
plot_rem_kde(park_df, 'Motor_Move_Waking')

# %% [markdown]
# This KDE plot illustrates the distribution of motor movements reports (0 = No, 1 = Yes) among the four study cohorts: Parkinson’s Disease, Healthy Controls, SWEDD, and Prodromal. The plot shows two density peaks for each group, one at 0 (no motor movements waking) and one at 1 (yes motor movements waking). The height of each peak reflects the proportion within each cohort that reported yes or no to whether or not they were woken up due to involuntary motor movements.
#
# Within each of our cohorts we can see that a larger amount of the population for Parkinson's diagnosed patients report more often that they are woken up because of motor movements. This fits expectations, since Parkinson's Disease is associated with nocturnal motor symptoms (rigidity, tremor, or kicking during sleep). In comparison Healthy controls have the lowest density at 1.0, indicating that waking due to movement is uncommon in this group.
#
# These differences within healthy and parkison's disease diagnosed cohorts show that motor-movement-related sleep disruption is clearly represented differently amongst these groups. The separation of distributions between cohorts supports the idea that nocturnal motor symptoms are a meaningful sleep-related marker of Parkinson’s disease.

# %%
plot_rem_kde(park_df, 'REM_Sleep_Disturbance')

# %% [markdown]
# This KDE plot illustrates the distribution of general REM sleep disturbances (0 = No, 1 = Yes) across Parkinson’s Disease, Healthy Controls, SWEDD, and Prodromal cohorts. As with the other REM-related variables, the density peaks at 0 and 1 represent the proportion of participants who do or do not experience REM sleep disturbances.
#
# The Parkinson’s and Prodromal groups show noticeably higher densities at 1.0, indicating greater rates of reported REM-related sleep disruption in these cohorts. This aligns with our beliefs of Parkinson’s disease, where neurodegeneration can disrupt REM sleep regulation.
#
# In comparison, healthy controls and SWEDD show the strongest density at 0, indicating that REM disturbances are the least common in individuals without underlying neurological disease. These patterns reinforce the idea that REM sleep disturbances are represented more strongly in Parkinson’s and Prodromal individuals than in healthy controls. This supports their potential role as indicators of Parkinson’s disease progression.

# %%
plot_rem_kde(park_df, 'Vivid_Dreams')

# %% [markdown]
# This KDE plot shows the distribution of vivid dream reports (0 = No, 1 = Yes) across the four cohorts: Parkinson’s Disease, Healthy Controls, SWEDD, and Prodromal. Just like the other REM-related measures, the plot displays two peaks per cohort—one at 0 and one at 1—with peak heights reflecting how frequently each cohort reports vivid dreams.
#
# Parkinson’s and Prodromal participants show higher densities at 1.0, meaning they report vivid dreams far more often than healthy controls. This is consistent with our hypothesis, as vivid dreams—and especially dream enactment—are closely linked to REM Sleep Behavior Disorder (RBD), one of the strongest prodromal markers of Parkinson’s disease.
#
# Healthy controls, on the other hand, show their highest peak at 0, indicating that vivid dreams are relatively uncommon. Overall, this plot suggests that vivid dreaming is more prevalent among those with Parkinson’s or at risk for Parkinson’s, reinforcing its relevance as a potential early symptom of neurodegeneration.
#
# We will look at whether genetic mutations and sleep are correlated

# %%
# REM vars and candidate genetic columns
rem_vars = ["REM_Sleep_Disturbance", "Motor_Move_Waking", "Vivid_Dreams"]
genetic_cols = [
    "ENRLPINK1", "ENRLPRKN", "ENRLSRDC", "ENRLNORM",
    "ENRLOTHGV", "ENRLHPSM", "ENRLRBD", "ENRLLRRK2",
    "ENRLSNCA", "ENRLGBA"
]
subset_cols = rem_vars + genetic_cols

rem_df = park_df.dropna(subset=subset_cols)

# keep only columns that exist in the dataframe
genetic_cols = [c for c in genetic_cols if c in rem_df.columns]
rem_vars = [r for r in rem_vars if r in rem_df.columns]

# create any_mutation flag: 1 if any listed gene == 1, else 0
gdf = rem_df[genetic_cols].apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)
rem_df["any_mutation"] = (gdf.sum(axis=1) > 0).astype(int)

# build numeric dataframe for correlation (fill NA with 0 for binary flags)
corr_cols = rem_vars + genetic_cols + ["any_mutation"]
corr_df = rem_df[corr_cols].apply(pd.to_numeric, errors="coerce").fillna(0)

# correlation matrix 
corr = corr_df.corr()

# REM vars vs any_mutation + individual genes
plot_cols = genetic_cols + ["any_mutation"]
subcorr = corr.loc[rem_vars, plot_cols]

plt.figure(figsize=(len(plot_cols)*0.6 + 2, len(rem_vars)*1.2 + 1))
sns.heatmap(subcorr, annot=True, fmt=".2f", cmap="vlag", center=0)
plt.title("Correlation (Pearson) between REM flags and gene mutations")
plt.xlabel("Gene / Any mutation")
plt.ylabel("REM variable")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_31540/136776105.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rem_df["any_mutation"] = (gdf.sum(axis=1) > 0).astype(int)

# %%
genetic_cols = [c for c in [
    "ENRLPINK1","ENRLPRKN","ENRLSRDC","ENRLNORM",
    "ENRLOTHGV","ENRLHPSM","ENRLRBD","ENRLLRRK2",
    "ENRLSNCA","ENRLGBA"
] if c in park_df.columns]

gene_df = park_df.copy()

if "any_mutation" not in gene_df.columns:
    gdf = gene_df[genetic_cols].apply(pd.to_numeric, errors="coerce").fillna(0).astype(int)
    gene_df["any_mutation"] = (gdf.sum(axis=1) > 0).astype(int)


# make Cohort numeric and map labels
gene_df["Cohort"] = pd.to_numeric(gene_df["Cohort"], errors="coerce").astype("Int64")
label_map = {1: "Parkinsons", 2: "Healthy Control", 3: "SWEDD", 4: "Prodromal"}

# summary table: counts and percent with any mutation per cohort
summary = gene_df.groupby("Cohort").agg(
    n_total=("any_mutation", "count"),
    n_with=("any_mutation", "sum")
).reset_index()
summary["pct_with"] = summary["n_with"] / summary["n_total"] * 100
summary["Cohort_label"] = summary["Cohort"].map(label_map).fillna(summary["Cohort"].astype(str))

print(summary[["Cohort_label", "n_with", "n_total", "pct_with"]])

# bar plot: percent with mutation by cohort
plt.figure(figsize=(8,4))
sns.barplot(data=summary, x="Cohort_label", y="pct_with", palette="viridis")
plt.ylim(0, 100)
plt.ylabel("Percent with any genetic mutation")
plt.title("Prevalence of any genetic mutation by Cohort")
for i, row in summary.iterrows():
    plt.text(i, row.pct_with + 1, f"{row.pct_with:.1f}%", ha="center")
plt.tight_layout()
plt.show()
# Out:
#       Cohort_label  n_with  n_total   pct_with
# 0       Parkinsons    1694     1960  86.428571
# 1  Healthy Control       0      440   0.000000
# 2            SWEDD       0       81   0.000000
# 3        Prodromal    5286     5291  99.905500
# /tmp/ipykernel_31540/1599856070.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=summary, x="Cohort_label", y="pct_with", palette="viridis")

# %%
summary.head()
# Out:
#    Cohort  n_total  n_with   pct_with     Cohort_label
# 0       1     1960    1694  86.428571       Parkinsons
# 1       2      440       0   0.000000  Healthy Control
# 2       3       81       0   0.000000            SWEDD
# 3       4     5291    5286  99.905500        Prodromal

# %% [markdown]
# Judging from the graph, another confounding variable we may not have accounted for are genetic mutations within the patients. In this graph it shows the prevalence of any patient that has at least one genetic mutation. This information could lead us to believe that parkinsons could be the result of underlying genetic mutations instead of sleep. However, we can not fully discount sleep quality as an indicator for parkinsons because it could be that sleep further contributes to the development of parkinsons alongside genetic mutations.
#
# To address this we can create a logistic regression model to show how sleep and prevalence of genetic diseases could impact parkinsons.

# %%
import statsmodels.formula.api as smf

new_df = pd.DataFrame({
    'Patient_num': park_df['Patient_Number'],
    'Parkinsons': (park_df['Cohort'].isin([1, 3, 4]).astype(int)),
    'Any_Mutation': park_df[genetic_cols].any(axis=1).astype(int),
    'Avg_ESS_Score': park_df['Avg_ESS_Score'],
    'RE_Disturbance': park_df['REM_Sleep_Disturbance'],
    'Vivid_Dreams': park_df['Vivid_Dreams'],
    'Move_Wake': park_df['Motor_Move_Waking']
})


new_df.head()
new_df.shape
# Out:
# (7772, 7)

# %%
model = smf.logit('Parkinsons ~ Any_Mutation', data=new_df).fit()
model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.070004
#          Iterations: 35
# /home/jgamba/anaconda3/envs/COGS108_FA25/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Parkinsons   No. Observations:                 7772
# Model:                          Logit   Df Residuals:                     7770
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 30 Nov 2025   Pseudo R-squ.:                  0.6782
# Time:                        19:39:05   Log-Likelihood:                -544.07
# converged:                      False   LL-Null:                       -1690.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.2231      0.072     -3.120      0.002      -0.363      -0.083
# Any_Mutation    25.1466   3091.286      0.008      0.994   -6033.662    6083.956
# ================================================================================
#
# Possibly complete quasi-separation: A fraction 0.90 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %% [markdown]
# There is a complete separation between groups meaning that all the patients with an genetic mutation also are a part of the Parkinsons cohort, SWEDD cohort, or the Prodromal cohort which all exhibit parkinsons related symptoms. The r-squared value is also greater than 0.05 which means we have not found any meaningful results. Lets now check whether or not there is a meaninful predictor of parkinsons.

# %%
model2 = smf.logit('Parkinsons ~ Avg_ESS_Score', data=new_df).fit()
model2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.266671
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Parkinsons   No. Observations:                 4464
# Model:                          Logit   Df Residuals:                     4462
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 30 Nov 2025   Pseudo R-squ.:                 0.01182
# Time:                        19:39:35   Log-Likelihood:                -1190.4
# converged:                       True   LL-Null:                       -1204.7
# Covariance Type:            nonrobust   LLR p-value:                 9.496e-08
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         1.9969      0.106     18.847      0.000       1.789       2.205
# Avg_ESS_Score     0.0906      0.018      5.094      0.000       0.056       0.125
# =================================================================================
# """

# %% [markdown]
# We can observe a more significant impact of sleepiness score and Parkinsons. The r-squared value is 0.01 which is indicates a siginificant result. The coefficient of Avg_ESS_Score shows us that the each point increase in average sleepiness increases the log likelihood of parkinosns by 0.0906. This indicates that for each point increase, probability of parkinsons increases by around 9.5 percent which can help us in rejecting our null hypothesis.

# %% [markdown]
# #### Section 3 of EDA -- NACC Dataset

# %%
nacc_df = pd.read_csv("data/02-processed/focused_nacc_data.csv")
nacc_df.head()
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
# Out:
#        NACCID  VISITYR  NACCETPR  NACCAGE  SEX  EDUC  RACE  NACCAPOE  \
# 0  NACC002909     2022       1.0     70.0    1  16.0   1.0       2.0
# 1  NACC002909     2024       1.0     71.0    1  16.0   1.0       2.0
# 2  NACC002909     2025       1.0     72.0    1  16.0   1.0       2.0
# 3  NACC003487     2023       NaN     66.0    1  16.0   1.0       6.0
# 4  NACC004352     2021       1.0     63.0    2  16.0   1.0       NaN
#
#    NACCNE4S  TOBAC30  ...  LBUMFACE  LBUMGAIT  LBUMPOST  LBUMBRAD  NACCACSF  \
# 0       1.0      0.0  ...       NaN       NaN       NaN       NaN       0.0
# 1       1.0      NaN  ...       NaN       NaN       NaN       NaN       0.0
# 2       1.0      NaN  ...       NaN       NaN       NaN       NaN       0.0
# 3       0.0      0.0  ...       NaN       NaN       NaN       NaN       0.0
# 4       NaN      0.0  ...       NaN       NaN       NaN       NaN       0.0
#
#    NACCPCSF  NACCTCSF  NACCLEWY  NPLBOD       Diagnosis
# 0       0.0       0.0       NaN     NaN      Alzheimers
# 1       0.0       0.0       NaN     NaN      Alzheimers
# 2       0.0       0.0       NaN     NaN      Alzheimers
# 3       0.0       0.0       NaN     NaN  Normal Control
# 4       0.0       0.0       NaN     NaN      Alzheimers
#
# [5 rows x 47 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# Ensure we are working with the loaded dataframe
df = nacc_df.copy()

# %% [markdown]
# 1. Setup and Library Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# Ensure we are working with the loaded dataframe
df = nacc_df.copy()

# %% [markdown]
# 2. Demographics and Class Balance
# Need to know if your "Normal Control" group is signficantly younger than your "Alzheimers" group, as the age is the biggest risk factor for sleep issues.

# %%
# 1. Diagnosis Counts
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='Diagnosis', data=df, palette='viridis', order=['Normal Control', 'Alzheimers', 'Lewy Body / PD'])
plt.title('Distribution of Diagnosis Groups')
plt.ylabel('Count')
plt.show()

# 2. Age Distribution by Diagnosis
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='NACCAGE', hue='Diagnosis', fill=True, common_norm=False, palette='viridis')
plt.title('Age Distribution by Diagnosis')
plt.xlabel('Age')
plt.show()

# Summary stats for Age
print(df.groupby('Diagnosis')['NACCAGE'].describe())
# Out:
# /tmp/ipykernel_333/949608491.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Diagnosis', data=df, palette='viridis', order=['Normal Control', 'Alzheimers', 'Lewy Body / PD'])
#                  count       mean       std   min   25%   50%   75%    max
# Diagnosis
# Alzheimers      6430.0  73.656454  9.412267  22.0  68.0  75.0  81.0  106.0
# Lewy Body / PD   487.0  71.870637  7.963245  45.0  67.0  72.0  77.0   97.0
# Normal Control  5415.0  71.460203  8.792430  21.0  66.0  72.0  77.0   97.0

# %% [markdown]
# 3. Sleep Metrics vs. Neurodegenerative Diagnosis
# Why: This directly addresses your hypothesis. We want to see if the rate of sleep issues increases in AD/PD groups compared to controls.

# %%
# List of binary/categorical sleep variables to check
# Note: We convert to numeric temporarily to calculate percentages easily
sleep_vars = ['NITE', 'HYPOSOM', 'RBD', 'CODSAWDY']
readable_names = ['Nighttime Awakening (NITE)', 'Insomnia (HYPOSOM)', 'REM Behavior Disorder (RBD)', 'Daytime Sleepiness']

fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.flatten()

for i, col in enumerate(sleep_vars):
    # Calculate percentage of "Yes" (1) for each diagnosis
    # We assume 1 = Present, 0 = Absent. 
    # We drop NAs to get accurate percentages of *reported* cases
    prop_data = df.groupby('Diagnosis')[col].value_counts(normalize=True).rename('percentage').reset_index()
    prop_data = prop_data[prop_data[col] == 1] # Only keep the "Yes" rows
    
    sns.barplot(x='Diagnosis', y='percentage', data=prop_data, ax=axes[i], palette='rocket', order=['Normal Control', 'Alzheimers', 'Lewy Body / PD'])
    axes[i].set_title(f'Prevalence of {readable_names[i]}')
    axes[i].set_ylabel('Proportion of Patients (0-1)')
    axes[i].set_ylim(0, 1.0) # Fix scale to see relative differences

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_333/593058672.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Diagnosis', y='percentage', data=prop_data, ax=axes[i], palette='rocket', order=['Normal Control', 'Alzheimers', 'Lewy Body / PD'])
# /tmp/ipykernel_333/593058672.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Diagnosis', y='percentage', data=prop_data, ax=axes[i], palette='rocket', order=['Normal Control', 'Alzheimers', 'Lewy Body / PD'])
# /tmp/ipykernel_333/593058672.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Diagnosis', y='percentage', data=prop_data, ax=axes[i], palette='rocket', order=['Normal Control', 'Alzheimers', 'Lewy Body / PD'])
# /tmp/ipykernel_333/593058672.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Diagnosis', y='percentage', data=prop_data, ax=axes[i], palette='rocket', order=['Normal Control', 'Alzheimers', 'Lewy Body / PD'])

# %% [markdown]
# 4. Cognitive Decline vs. Sleep (Boxplots)
# Why: To see if people with sleep issues actually have lower cognitive scores (MMSE).

# %%
plt.figure(figsize=(10, 6))
# We filter out -4 or NaN MMSE scores first
valid_mmse = df.dropna(subset=['NACCMMSE', 'NITE'])

sns.boxplot(x='NITE', y='NACCMMSE', hue='Diagnosis', data=valid_mmse, palette='Set2')
plt.title('Cognitive Score (MMSE) vs. Nighttime Awakening')
plt.xlabel('Nighttime Behaviors Present (0=No, 1=Yes)')
plt.ylabel('MMSE Score (Lower is worse)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# 5. The Confounder Check: Depression vs. Sleep
# Why: Depression is a major confounder. If all the bad sleepers are just depressed, then the neurodegeneration link is weak. Should visualize this relationship.

# %%
print([col for col in df.columns if "DEP" in col]) #"DEP' not in col
import matplotlib.pyplot as plt
import seaborn as sns

# Correlation Matrix for Key Numeric Variables + Boolean Sleep
# I removed 'DEPRS' since it is missing from your dataframe
corr_cols = ['NACCAGE', 'NACCMMSE', 'NITE', 'HYPOSOM', 'RBD']

# Ensure they are numeric for correlation
# We verify these columns exist before selecting them to avoid another KeyError
available_cols = [c for c in corr_cols if c in df.columns]
corr_df = df[available_cols].apply(pd.to_numeric, errors='coerce')

plt.figure(figsize=(10, 8))
sns.heatmap(corr_df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix: Sleep and Cognition')
plt.show()
# Out:
# []

# %% [markdown]
# 6. Visualizing Missingness (Addressing Limitations)
# Why: Explicitly mentioned missingness in biomarkers and detailed sleep data (LBSPDRM) as a limitation.

# %%
# %pip install missingno
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: missingno in /home/sisrani/.local/lib/python3.11/site-packages (0.5.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (from missingno) (3.8.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from missingno) (1.13.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib->missingno) (2.9.0)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.11/site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# Select variables with known missingness issues vs core variables
missing_check_cols = ['Diagnosis', 'NACCAGE', 'NITE', 'LBSPDRM', 'CONSFALL', 'NACCACSF', 'NPLBOD']

msno.matrix(df[missing_check_cols].sample(500)) # Sample 500 to make the plot readable
plt.title('Missing Data Patterns (White = Missing)')
plt.show()

# Print actual % missing per diagnosis for a specific tricky variable
print("Missingness of 'Dream Enactment' (LBSPDRM) by Diagnosis:")
print(df.groupby('Diagnosis')['LBSPDRM'].apply(lambda x: x.isna().mean()))
# Out:
# Missingness of 'Dream Enactment' (LBSPDRM) by Diagnosis:
# Diagnosis
# Alzheimers        0.998312
# Lewy Body / PD    0.922131
# Normal Control    0.998718
# Name: LBSPDRM, dtype: float64

# %% [markdown]
# Our EDA of the NACC dataset was designed to validate whether subjective sleep metrics could serve as reliable predictors for Alzheimer's progression. In the analysis, we observed several key trends and data limitations that shaped our modeling strategy. In our representation, Alzheimher's patients constitute the largest cleaned dataset cohort, having approximately 6,517 observations compared to around 5,400 normal controls. Morevoer, our analysis included examining the age distributions to verify if the AD (Alzheimer's Disease) cohort is significantly older than the control group as a primary risk factor.
#
# In our findings, we identified that AD patients exhibit elevated rates of general sleep disturbances, specifically Nighttime Awakening (NITE) and Daytime Sleepiness (CODSAWDY) compared to healthy controls. And unike the Lewy Body/Parkinson's group (LBD/PD), the AD cohort doens't show a strong prevlance of REM Sleep Behavior Disorder (RBD) or dream enactment, which serves as a key differentiator for AD diagnosis in this dataset.
#
# Our EDA also indicated a general trend/correlation where increased sleep fragmentation (lower sleep quality) (NITE) aligns with lower cognitive scores (NACCMMSE, Mini-Mental State Exam) within the neurodegenerative groups like AD. Another crucial finding we got was that sleep disturbances in the AD group correlate with depression scores (DEPRS). This suggests that some reported sleep issues may be driven by mood disorders rather than neurodegerantion alone, showing a potential confounding variable.
#
# However, analysis of the NACC datset revealed that some "gold standard" biological indicators for AD (CSF Amyloid Beta and Tau levels) suffer from high levels (>90%) of missingness. This systematic gap limits the ability to link sleep metrics directly to physiological AD pathology and forces a stronger reliance on clinical diagnoses instead.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# If we were to give out a survey to students at UCSD or other adults, we would ask for their consent on whether or not they would like to give out personal details such as how much sleep they have had or any history with neurodegenerative diseases. A consent form for each of the surveys would ensure that we are not collecting personal information from people who would not like to share it to the public.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# To account for biases within the data we collect, we will collect from a multitude of sources and validate the contents of the data collected within each source. If a source does not meet our threshold for the amount of data we need to be able to do effective analysis, then we will not utilize it in our predictions. Additionally, we will attempt to account for any factors such as demographics within the data we collect so that our outcomes are more representative of the entire population.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  If we were to collect data from surveys we send out to other students, then we would make the effort to keep the personal information as anonymous as possible so that we could control for factors such as race, gender, or any other determining factors. We will only collect relevant data that helps us answer our research question.
#
#  - [] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
#  All data collected and the analysis done to this data will be freely available to our entire team and the course staff. It is up to the course staff’s discretion on whether our project and its contents are able to be seen by third parties. As our main sources of information are found through the internet, the data has already been made publicly available, so we are only sharing information that has already been shared by other projects.
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# We have considered the possibility of biased data and we will try to guarantee that we will not view data with prior assumptions, instead we will validate the results alone and make informed predictions about how such data could apply to our goals for the project. To address these biases, we will also be mindful of where our sources come from and also focus only on variables necessary for our project. On the issue of stereotype perpetuation, we will examine our data carefully so that we are not merely looking for causality, but instead taking into account the nuances of degenerative disorders and the people who experience them.
#
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
#  Our graphs and visualizations will be as clear and data driven as possible. We will attempt to minimize the likelihood of our visualizations implying a message that our group did not intend to convey. Underlying data will be explained to ensure that each visualization can not be misinterpreted. We will emphaisize that correlation does not indicate causation and some visualizations will only be serving the purpose of showing relationships between variables and should not be considered as our conclusions about the data being observed.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
#  We will practice tidy data and clean data wrangling to focus our efforts on the data that directly coincides with the goals of the project. We will omit any data that does not directly affect or relate to the variables we will be analyzing.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#  Our data process will be thoroughly documented which will allow anyone in the future to view our project and validate the results of our analysis. Every step from the data wrangling to the visualizations, to all the issues we faced will be written down to describe every process we went through to arrive at our conclusions.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
#  Our analysis focuses on sleep-related metrics (ex: sleep duration, sleep apnea events, sleep quality, REM sleep behavior) and clinical data. Using this, and being cautious about including demographic data that could be representative/ a proxy for certain protected characteristics, our goal is to ensure that any predictive power comes from biological and behavioral factors directly related to sleep and health and not from variables that might introduce societal biases like demographics, ethnicity, age groups, generations, etc.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
#  With our dataset containing demographic information such as age, sex, or race, we plan to evaluate our model’s performance across these different subgroups, but we will check for disparities like false positive and false negative rates in these key metrics to test the model results for fairness with respect to different demographically affected groups to ensure the predictive analysis has no basis on it. And if our model is significantly less accurate for one compared to another group, in our final report we would document and record this disparate rate and discuss its potential implications on ethics and fairness, even if we can’t fully mitigate it because of its training and ingrained biases systemic in the variables’ relationships within the scope of the project. And another question is evaluating whether or not the model is better with or without those ingrained metrics.
#
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
#  Predicting the risk of neurodegenerative diseases, we won’t rely solely on accuracy as our primary metric, and we will prioritize metrics accounting for the cost of incorrect predictions to optimize for considering the effects of optimizing for our defined metrics with model optimization impacts. Specifically focusing on sensitivity (ability to correctly identify individuals at risk) and specificity (ability to correctly identify individuals NOT at risk) and highlighting the trade-off between the two will help us aim for a balance that avoids incorrect metrics like high false positives with an alarm and missing potential cases like high false negatives too as an additional metric to show effects of model optimization and when it comes to an overextent. We will also consider additional metrics like the F1-score and AUC-ROC and other ML metrics to get a more sophisticated and comprehensive view of model performance.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
#  Starting with simpler, more transparent models like logistic regression or decision trees to establish a baseline and understand the key predictive features helps with model interpretability before getting into obscure algorithms. Using more complex black-box models like gradient boosting, DL, neural networks, if we plan to employ these types of corresponding techniques to analyze feature importance and explain the model’s predictions then a justification will definitely be more needed because the model isn’t as clear in its results and understandable terms for a decision so more explanation is needed. As a health-related topic, being able to explain why the model made a certain prediction at all times is crucial for trust and understanding in results though.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#  In our final report and presentation, we will definitely dedicate specific sections to discuss the limitations of our model and tradeoffs. Including any known biases, demographic-based ingrained predispositions, and flaws in our source data, we can show performance trade-offs we had to make and give a clear statement into what our model identifies as correlations and not casual or misconstrued relationships. Approaching it from an educational and exploratory purpose and perspective also helps in showing the applicability of it to clinical and diagnostic real-world situations.
#
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
#  Our evaluation will consist of testing the model’s data on various more training datasets even after deployment to identify skews in performance execution and see if the model is still working to its fullest capacity. The final performance at the analysis and report will be documented thoroughly, and ongoing monitoring with active predictions can be made using another algorithm to match its predictions from a different approach to uncover any biases that might arise from data changes or incorrect errors as a result too. Having robust evaluation metrics for regular audits and performance monitoring and human review and future impact and biases concept basis through evaluating accuracy, understanding sensitivity tradeoff between false positives and false negatives, maximizing recall (minimizing false negatives) in settings, prioritizing at risk individuals, and also evaluating using the F1-score harmonic mean, other model metrics, and the AUC-ROC curve to compare performances across all thresholds, also cross validation, error analysis, peer review and more are all important for post deployment challenges and model auditing.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
#  A mechanism for user harm and a formal redress process include meetings with the primary stakeholders, evaluating product goals and concept drift, insurance policies, and if errors are found in our analysis or conclusions from investigations after user harm, the redress plan will involve acknowledging these mistakes, understanding what went wrong, and documenting the correct approach, fulfilling the educational objective of this mistake, and compensating injury in any medium necessary, all preventing future harms through re-investigation of the model.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  For rolling back in a live production environment, the stakes are much higher, requiring planned, systematic approaches to minimize disruption. An immediate and reliable rollback mechanism is critical. If the new model starts making erroneous predictions, we can instantly switch traffic fro a poorly performing new model back to the last known stable model version using version control on github from our updates. This ensures the final product can always revert to one free of biases and without erroneous error disparities and harmful results. Shifting production traffic quickly is the perfect solution for this issue in ethics and deployment environments.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#  The main foreseeable unintended use and consequence would be misinterpreting our model, used for educational purposes and with its idea having no harm inherently, and its findings as medical advice, as it is educational and experimental only and hasn’t been tested on the medical stories and complexities of health issues in all types of patients despite demographic testing it can’t process a multitude of variables and link them at a time like two different diseases, etc. Stressing the correlational (and possibly more to determine and uncover true relationships that exist) nature of our findings and the model’s limitations to discourage misuse and that correlation does not imply causation in our specified conclusion should be the steps we take the identity and prevent unintended uses and abuses of the model and monitoring it as such after deployment with disclaimers and more factors.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: Replace this with your timeline.  **PLEASE UPDATE your Timeline!** No battle plan survives contact with the enemy, so make sure we understand how your plans have changed.  Also if you have lost points on the previous checkpoint fix them
